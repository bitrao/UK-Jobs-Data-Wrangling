# %% [markdown]
# # Jobs Data Integration
#
# Libraries used:
# * pandas
# * numpy
#
# ## Introduction
# Merge the cleaned dataset with new dataset that are from 'www.jobhuntlisting.com'. However, the dataset are in different format, **schematic mapping** is applied to resolve the conflict before merge. Data conflicts are also be considered and handle.

# %% [markdown]
# ##  Import libraries

# %%
import pandas as pd
import numpy as np

# display configuration
from IPython.display import display

pd.set_option('display.max_rows', None)  
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 1. Examining and loading data
# Examine "dataset2.csv".

# %%
df = pd.read_csv('dataset2.csv')

df.head(5)
# Out:
#     Location                                          Job Title  \
# 0  Berkshire                                        Lead CRA UK
# 1    Bristol                                 Possession Manager
# 2   Coventry  NVQ Assessor Banking/Financial Services Salary...
# 3      Poole                      HEAD OF CARE (RGN/RMN)  Poole
# 4     Woking                                     SQL Server DBA
#
#    Monthly Payment              Closing                Category       Type  \
# 0          4583.33  2012-03-08 12:00:00                  Health        NaN
# 1          2812.50  2013-09-06 12:00:00             Engineering  Permanent
# 2          1791.67  2013-05-02 00:00:00             Hospitality  Permanent
# 3          2916.67  2013-09-24 15:00:00                  Health        NaN
# 4          3125.00  2012-12-21 12:00:00  Information Technology        NaN
#
#                Opening      Organisation  Full-Time Equivalent (FTE)
# 0  2012-01-08 12:00:00   SEC Recruitment                         1.0
# 1  2013-08-07 12:00:00  Navartis Limited                         1.0
# 2  2013-02-01 00:00:00          Pertemps                         1.0
# 3  2013-07-26 15:00:00       Team 24 Ltd                         1.0
# 4  2012-11-21 12:00:00         Matchtech                         1.0

# %%
print('\n____________ Dataset info ____________')
display(df.info())              
print('\n____________ Statistics of numerical features ____________')
display(df.describe())  
print('\n____________ Statistics of literal features ____________')
display(df.describe(include=[object]))
# Out:
# ____________ Dataset info ____________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Location                    5000 non-null   object
#  1   Job Title                   5000 non-null   object
#  2   Monthly Payment             5000 non-null   float64
#  3   Closing                     5000 non-null   object
#  4   Category                    5000 non-null   object
#  5   Type                        3593 non-null   object
#  6   Opening                     5000 non-null   object
#  7   Organisation                4531 non-null   object
#  8   Full-Time Equivalent (FTE)  5000 non-null   float64
# dtypes: float64(2), object(7)
# memory usage: 351.7+ KB
# None
# ____________ Statistics of numerical features ____________
#        Monthly Payment  Full-Time Equivalent (FTE)
# count      5000.000000                  5000.00000
# mean       2854.147972                     0.98560
# std        1310.434763                     0.09236
# min         424.000000                     0.20000
# 25%        1916.670000                     1.00000
# 50%        2583.330000                     1.00000
# 75%        3541.670000                     1.00000
# max        8000.000000                     1.00000
# ____________ Statistics of literal features ____________
#        Location    Job Title              Closing                Category  \
# count      5000         5000                 5000                    5000
# unique      431         5000                 2062                       8
# top          UK  Lead CRA UK  2013-01-11 12:00:00  Information Technology
# freq        753            1                    8                    1251
#
#              Type              Opening   Organisation
# count        3593                 5000           4531
# unique          2                 1967           2481
# top     Permanent  2013-12-09 00:00:00  UKStaffsearch
# freq         3034                   12             52

# %% [markdown]
# ##### Import the cleaned dataset from previous task

# %%
df_dataset1 = pd.read_csv('cleaned_dataset1.csv')

df_dataset1.head()
# Out:
#          Id                                              Title  \
# 0  68677473  Fluent Polish Speaking Incident Manager Krakow...
# 1  71851065  GIS Trainer  Central London  Permanent  ****k*...
# 2  68665487                         Trafficker/Ad Op's Manager
# 3  68685701                              PR Associate Director
# 4  66960212                     Accounts Payable Administrator
#
#             Location                          Company   ContractType  \
# 0                 UK                          Proxime  non-specified
# 1             London               Locum Staffing Ltd  non-specified
# 2  South East London                Savvy Media Group  non-specified
# 3        Oxfordshire                 Pure Recruitment  non-specified
# 4      Littlehampton  The Recruitment Consultancy Ltd  non-specified
#
#   ContractTime                          Category   Salary  \
# 0    permanent                           IT Jobs   6000.0
# 1    permanent                           IT Jobs  40000.0
# 2    permanent                           IT Jobs  40000.0
# 3     contract  PR, Advertising & Marketing Jobs  55000.0
# 4    permanent         Accounting & Finance Jobs  35500.0
#
#               OpenDate            CloseDate     SourceName
# 0  2013-11-02 15:00:00  2014-01-31 15:00:00  totaljobs.com
# 1  2012-04-30 15:00:00  2012-05-30 15:00:00  totaljobs.com
# 2  2012-08-27 15:00:00  2012-10-26 15:00:00  totaljobs.com
# 3  2012-03-15 15:00:00  2012-03-29 15:00:00  totaljobs.com
# 4  2012-07-23 00:00:00  2012-10-21 00:00:00  totaljobs.com

# %%
df_dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50753 entries, 0 to 50752
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            50753 non-null  int64
#  1   Title         50753 non-null  object
#  2   Location      50753 non-null  object
#  3   Company       48882 non-null  object
#  4   ContractType  50753 non-null  object
#  5   ContractTime  50753 non-null  object
#  6   Category      50753 non-null  object
#  7   Salary        50753 non-null  float64
#  8   OpenDate      50753 non-null  object
#  9   CloseDate     50753 non-null  object
#  10  SourceName    50753 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.3+ MB

# %% [markdown]
# ### 2. Resolving schema conflicts
# Give some general information about the conflicts you found in two schemas and steps you taken to resolve them.

# %% [markdown]
# #### 2.1. Id
# Generate 8 digits Id for `df`.

# %%
ids = np.random.randint(10000000, 100000000, size=len(df))

# %%
# assign Id 
df['Id'] = ids

# %% [markdown]
# #### 2.2. Columns Name
# - Certain columns share the same value type with `df_dataset1` schema => rename those columns
# ##### Rename Columns

# %%
# rename the column following the schema of the previous df
df.rename(columns = {'Job Title':'Title', 'Closing':'CloseDate', 'Type':'ContractTime',
                             'Closing':'CloseDate', 'Opening': 'OpenDate', 'Organisation' : 'Company'}, inplace = True)

# %% [markdown]
# #### 2.3. Contract Type
# Use `Full-Time-Equivalent` to determine the contract type:
#
# - **1.0** means the jobs are full-time employment.
# - **others** means the jobs are part-time employment.

# %%
# fill the ContractType
df['ContractType'] = df['Full-Time Equivalent (FTE)'].apply(lambda x: 'full_time' if x == 1.0 else 'part_time')

# %%
# examine the ContractType values
df['ContractType'].value_counts()
# Out:
# ContractType
# full_time    4857
# part_time     143
# Name: count, dtype: int64

# %% [markdown]
# #### 2.4: Contract Time
# Check whether there are missing values. If there are any, fill those with **'non-specified'**

# %%
# examine ContractTime missing values
df['ContractTime'].isna().sum()
# Out:
# 1407

# %%
# fill the missing values
df['ContractTime'].fillna('non-specified',inplace=True)

# %% [markdown]
# Check the values of the `ContractTime`

# %%
df['ContractTime'].value_counts()
# Out:
# ContractTime
# Permanent              3034
# non-specified          1407
# Fixed Term Contract     559
# Name: count, dtype: int64

# %% [markdown]
# The values are not in the schema format:
#
# - **Permanent** need to be changed to **permanent**
# - **Fixed Term Contract** need to be changed to **contract**

# %%
contract_time_dict = {'Permanent':'permanent','Fixed Term Contract': 'contract'}

df['ContractTime'].replace(contract_time_dict,inplace=True)

# examine the fixed ContractTime
df['ContractTime'].value_counts()
# Out:
# ContractTime
# permanent        3034
# non-specified    1407
# contract          559
# Name: count, dtype: int64

# %% [markdown]
# #### 2.5. Category

# %%
df['Category'].value_counts()
# Out:
# Category
# Information Technology    1251
# Health                     804
# Engineering                732
# Finance                    675
# Sales                      517
# Hospitality                436
# Education                  341
# Marketing                  244
# Name: count, dtype: int64

# %% [markdown]
# Category in this `df` also has 8 values that happened to be corresponding to those in the required schema.
#
# => Change to those following the values in the required schema.

# %%
category_dict = {'Information Technology':'IT Jobs','Health': 'Healthcare & Nursing Jobs', 'Engineering': 'Engineering Jobs', 
                'Finance': 'Accounting & Finance Jobs', 'Sales': 'Sales Jobs', 'Hospitality': 'Hospitality & Catering',
                 'Education': 'Teaching Jobs', 'Marketing': 'PR, Advertising & Marketing Jobs'}

df['Category'].replace(category_dict,inplace=True)

# examine the fixed Category
df['Category'].value_counts()
# Out:
# Category
# IT Jobs                             1251
# Healthcare & Nursing Jobs            804
# Engineering Jobs                     732
# Accounting & Finance Jobs            675
# Sales Jobs                           517
# Hospitality & Catering               436
# Teaching Jobs                        341
# PR, Advertising & Marketing Jobs     244
# Name: count, dtype: int64

# %% [markdown]
# #### 2.6. Salary
# `Salary` is calculated by multiplying the `Monthly Payment`

# %%
# create Salary column
df['Salary'] = df['Monthly Payment']*12

# %% [markdown]
# #### Conflict 7: Open Date and Close Date
# Change to datetime format

# %%
df['OpenDate'] = pd.to_datetime(df['OpenDate'], utc=True).dt.tz_convert(None)
df['CloseDate'] = pd.to_datetime(df['CloseDate'], utc=True).dt.tz_convert(None)

# examine the data type of OpenDate and CloseDate
df[['OpenDate', 'CloseDate']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   OpenDate   5000 non-null   datetime64[ns]
#  1   CloseDate  5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](2)
# memory usage: 78.2 KB

# %% [markdown]
# #### Conflict 8: Source Name
# Fill the `SourceName` with 'www.jobhuntlisting.com'

# %%
# create and fill the sourcename column
df['SourceName'] = 'www.jobhuntlisting.com'

# %% [markdown]
# #### Conflict 9: Valid columns and their orders

# %%
# examine current df
df.head(3)
# Out:
#     Location                                              Title  \
# 0  Berkshire                                        Lead CRA UK
# 1    Bristol                                 Possession Manager
# 2   Coventry  NVQ Assessor Banking/Financial Services Salary...
#
#    Monthly Payment           CloseDate                   Category  \
# 0          4583.33 2012-03-08 12:00:00  Healthcare & Nursing Jobs
# 1          2812.50 2013-09-06 12:00:00           Engineering Jobs
# 2          1791.67 2013-05-02 00:00:00     Hospitality & Catering
#
#     ContractTime            OpenDate           Company  \
# 0  non-specified 2012-01-08 12:00:00   SEC Recruitment
# 1      permanent 2013-08-07 12:00:00  Navartis Limited
# 2      permanent 2013-02-01 00:00:00          Pertemps
#
#    Full-Time Equivalent (FTE)        Id ContractType    Salary  \
# 0                         1.0  91469173    full_time  54999.96
# 1                         1.0  21088325    full_time  33750.00
# 2                         1.0  41064446    full_time  21500.04
#
#                SourceName
# 0  www.jobhuntlisting.com
# 1  www.jobhuntlisting.com
# 2  www.jobhuntlisting.com

# %% [markdown]
# `Monthly Payment` and `Full-Time Equivalent (FTE)` are not in the required schema.

# %%
# drop unnecessary column
df = df.drop(columns = ['Monthly Payment', 'Full-Time Equivalent (FTE)'])

# %% [markdown]
# ##### Rearrange the columns order following the required schema

# %%
# rearrange the columns
df = df[['Id', 'Title', 'Location', 'Company', 'ContractType', 'ContractTime', 'Category', 'Salary', 'OpenDate', 'CloseDate', 'SourceName']]

# examine the newly form df
df.head(3)
# Out:
#          Id                                              Title   Location  \
# 0  91469173                                        Lead CRA UK  Berkshire
# 1  21088325                                 Possession Manager    Bristol
# 2  41064446  NVQ Assessor Banking/Financial Services Salary...   Coventry
#
#             Company ContractType   ContractTime                   Category  \
# 0   SEC Recruitment    full_time  non-specified  Healthcare & Nursing Jobs
# 1  Navartis Limited    full_time      permanent           Engineering Jobs
# 2          Pertemps    full_time      permanent     Hospitality & Catering
#
#      Salary            OpenDate           CloseDate              SourceName
# 0  54999.96 2012-01-08 12:00:00 2012-03-08 12:00:00  www.jobhuntlisting.com
# 1  33750.00 2013-08-07 12:00:00 2013-09-06 12:00:00  www.jobhuntlisting.com
# 2  21500.04 2013-02-01 00:00:00 2013-05-02 00:00:00  www.jobhuntlisting.com

# %% [markdown]
# ### 3. Merging data
# Merge two dataframe vertically with `concat`

# %%
# concat the df_dataset1 with df
merged_df = pd.concat([df_dataset1, df], ignore_index=True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55753 entries, 0 to 55752
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            55753 non-null  int64
#  1   Title         55753 non-null  object
#  2   Location      55753 non-null  object
#  3   Company       53413 non-null  object
#  4   ContractType  55753 non-null  object
#  5   ContractTime  55753 non-null  object
#  6   Category      55753 non-null  object
#  7   Salary        55753 non-null  float64
#  8   OpenDate      55753 non-null  object
#  9   CloseDate     55753 non-null  object
#  10  SourceName    55753 non-null  object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 4.7+ MB

# %% [markdown]
# ### 4. Resolving data conflicts:

# %% [markdown]
# #### 4.1. Duplicates Check

# %%
duplicates = merged_df[merged_df.duplicated()]

print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Id, Title, Location, Company, ContractType, ContractTime, Category, Salary, OpenDate, CloseDate, SourceName]
# Index: []

# %% [markdown]
# There are **no entries** that share the exact data together.
#
# `Id` can be used to be the **global key** due to its uniqueness
#
# => It needs to be check whether there are duplication in this column
# ##### Check duplicate Id

# %%
duplicates_Id = merged_df[merged_df.duplicated(subset=['Id'])]

print("Duplicates based on Id:")
display(duplicates_Id)
# Out:
# Duplicates based on Id:
#              Id                                              Title  \
# 53192  68996751  Pastry Chef de Partie  Food Focused MultiOutle...
# 53679  67903611        Senior Developer (x ****)  Flash/OOD/AS****
#
#                   Location        Company ContractType   ContractTime  \
# 53192             Cheshire   Chef Results    full_time  non-specified
# 53679  Newcastle Upon Tyne  Computappoint    full_time      permanent
#
#                      Category    Salary             OpenDate  \
# 53192  Hospitality & Catering  17000.04  2012-01-21 15:00:00
# 53679                 IT Jobs  37500.00  2012-06-01 12:00:00
#
#                  CloseDate              SourceName
# 53192  2012-03-21 15:00:00  www.jobhuntlisting.com
# 53679  2012-07-01 12:00:00  www.jobhuntlisting.com

# %% [markdown]
# ##### Handle duplicate Id
# - Define a unique 8 digits Id generator that check with the current Ids
# - Replace those entries that have duplicate Id with the newly created Id.

# %%
def generate_unique_8_digit_id(existing_ids):
    while True:
        new_id = np.random.randint(10000000, 100000000)
        if new_id not in existing_ids:
            return new_id

# replace duplicate IDs with new 8-digit unique IDs
existing_ids = set(merged_df['Id']) # get the set of current Id

for idx in duplicates_Id.index:
    new_id = generate_unique_8_digit_id(existing_ids)
    merged_df.at[idx, 'Id'] = new_id
    existing_ids.add(new_id)  # update the set of existing IDs with the new ID

# %%
# check whether there are duplicate Id
duplicates_Id = merged_df[merged_df.duplicated(subset=['Id'])]

print("Number of duplicates based on Id:")
display(duplicates_Id.shape[0])
# Out:
# Number of duplicates based on Id:
# 0

# %% [markdown]
# No entries have duplicate Ids left.
#
# => `Id` could be use as global key as the column values are unique.

# %% [markdown]
# #### Conflict 2: Check duplication based on the title and company
# Jobs advertisement that share the same title and company are consider to be duplicated.

# %%
duplicates_jobs = merged_df[merged_df.duplicated(subset=['Title', 'Company'])]
print("Duplicates based on title and company:")
display(duplicates_jobs)
# Out:
# Duplicates based on title and company:
#              Id                                              Title  \
# 37676  64796965                            Year 1 Teacher Stanmore
# 38775  64796947                                 Casino VIP Manager
# 50753  91469173                                        Lead CRA UK
# 50775  44156135                                      CE I Designer
# 50782  39964967                   Legal Publishing Account Manager
# 50824  39781314   Internal Sales Account Manager Wigan ****kOTEBEN
# 50832  61489480                 Renal Healthcare Technician Oxford
# 50850  43213850  IT SALES – ACCOUNT MANAGER  ERP & FINANCIAL / ...
# 50853  14547755                                    Field Sales Rep
# 50861  69129114                        Sponsorship Account Manager
# 50890  50594334  Trainee Recruitment Consultants Required City ...
# 50962  61748689                 Maintenance Lead Hand (electrical)
# 50968  72866051   Sales Support – UK, SE Eng – ****  Asset Finance
# 50971  78985039       Java Developer | HTML, CSS, JavaScript, Java
# 50974  15636841         ERP Application Support Analyst/Programmer
# 50981  40307846  SOUS CHEF  PREMIUM RESTAURANT GROUP IN CHICHES...
# 50989  46621185          Senior Application Support Team Lead  eFX
# 50990  30694307  General Manager New Restaurant Opening Growing...
# 50998  39297029    BAND 5 RGN  LEICESTER AND NOTTINGHAM  Leicester
# 51010  83254093                               Press Shop Operative
# 51014  76441201  Technical Support / Application Support  Banki...
# 51064  38394251                         Part Quallified Accountant
# 51077  67528229  Technical Support/Application Support  payment...
# 51112  89098162    Sales Professionals Building Materials Midlands
# 51145  88255068                                Telecoms Technician
# 51146  48445160            Electro/Mechanical Maintenance Engineer
# 51173  37430262                         Auto Electrical Technician
# 51178  96033851               Sharepoint Infrastructure Consultant
# 51185  71850148                 Optometrists Jobs in Milton Keynes
# 51201  76772662                    Salesforce Technical Consultant
# 51206  83224060           Russian speaking Forex Marketing Manager
# 52002         South East London
# 52060                  Brighton
# 52104                 Bracknell
# 52106                    London
# 52127               Northampton
# 52129                    London
# 52188               Northampton
# 52228             West Midlands
# 52253              Chesterfield
# 52259                  Cheshire
# 52278                    London
# 52283                   Fareham
# 52337                 Liverpool
# 52346        North East England
# 52348                        UK
# 52356             Milton Keynes
# 52397                    London
# 52406               Northampton
# 52423                Cheltenham
# 52440             East Midlands
# 52447               Southampton
# 52454                    London
# 52475                    London
# 52476                        UK
# 52495              Burgess Hill
# 52496                     Leeds
# 52504            Central London
# 52509                        UK
# 52527                    Dorset
# 52532                    London
# 52550                    London
# 52558                    London
# 52574                   Windsor
# 52578                   Runcorn
# 52714             West Midlands
# 52723                   Watford
# 52770               Northampton
# 52852                    Surrey
# 52856                        UK
# 52866                        UK
# 52897         South East London
# 52900                   Norwich
# 52910         South East London
# 52913                    London
# 52920                 Stevenage
# 52923           Nottinghamshire
# 52924                        UK
# 52927                Midlothian
# 53017                    Harrow
# 53036         South East London
# 53042                Birmingham
# 53064                 Hampshire
# 53087                   Byfleet
# 53095                      Bury
# 53100                     Wales
# 53102             Hertfordshire
# 53105                  The City
# 53109                Chelmsford
# 53114                  Brighton
# 53119                    London
# 53138                        UK
# 53151                  Coventry
# 53161                    London
# 53172               Cirencester
# 53198                Colchester
# 53229                East Sheen
# 53275                    London
# 53281                     Corby
# 53288         South East London
# 53292         South East London
# 53293                        UK
# 53319                   Crawley
# 53331                    London
# 53341                        UK
# 53350                Portsmouth
# 53353                    London
# 53391                      Kent
# 53393                        UK
# 53445            West Yorkshire
# 53454                        UK
# 53467                        UK
# 53478                        UK
# 53508                  Brighton
# 53532             Kidderminster
# 53536                        UK
# 53538                    London
# 53668                    Newark
# 53704                    Surrey
# 53724                 Northwich
# 53734                 Bracknell
# 53746                    Woking
# 53747                    London
# 53749                Birmingham
# 53767                   Fareham
# 53792                Folkestone
# 53795                    London
# 53842                    London
# 53853               Farnborough
# 53857                  Hounslow
# 53890                    London
# 53930      Edinburgh Technopole
# 53945                   Swanley
# 53969                 Sheffield
# 53974                 Kettering
# 54020                  Wetherby
# 54025                        UK
# 54028                 Aylesbury
# 54032                  Tadworth
# 54035                   Reading
# 54062                   Andover
# 54067             West Midlands
# 54074                    London
# 54088                 Blackpool
# 54094                    London
# 54131              West Malling
# 54139            Cambridgeshire
# 54140         South East London
# 54169                    London
# 54198                    London
# 54201                    Oxford
# 54203                     Essex
# 54205                 Wakefield
# 54214                        UK
# 54230                    London
# 54266                     Frome
# 54283             Hertfordshire
# 54292                   Clifton
# 54303                  Richmond
# 54306             Milton Keynes
# 54310                    London
# 54313                   Belfast
# 54316                     Corby
# 54331       Marton-In-Cleveland
# 54333                Manchester
# 54369                 Harrogate
# 54378                    Marlow
# 54406                Gloucester
# 54419                    Ilford
# 54467                   Skipton
# 54480                    London
# 54487            Leicestershire
# 54490                   Reading
# 54491                 Southport
# 54493                Portsmouth
# 54507            West Yorkshire
# 54539              Peterborough
# 54559                    London
# 54565        South West England
# 54568                        UK
# 54569                 Sevenoaks
# 54606                    London
# 54634                     Truro
# 54656              West Malling
# 54676             Hertfordshire
# 54710              Warwickshire
# 54715                     Leeds
# 54734                    Dorset
# 54822                   Newbury
# 54826              North London
# 54828                        UK
# 54830         South East London
# 54838                  Bradford
# 54844                      Kent
# 54906                Nottingham
# 54942                   Swindon
# 54968                        UK
# 54982                      Kent
# 54997                 Horsforth
# 55001                        UK
# 55009                 Worcester
# 55021                  Cornwall
# 55027                 Cambridge
# 55036                   Reading
# 55064                        UK
# 55095               Petersfield
# 55108                        UK
# 55120            Leicestershire
# 55124                    Woking
# 55125              Burgess Hill
# 55166                 Sevenoaks
# 55174               Potters Bar
# 55175                Birmingham
# 55201                   Glasgow
# 55223                        UK
# 55233                    London
# 55238  Yorkshire and Humberside
# 55240                East Sheen
# 55255                      Hove
# 55353                    London
# 55374                 Sheffield
# 55381                St. Albans
# 55398        South West England
# 55410                   Prescot
# 55424               Scarborough
# 55428                   Chorley
# 55456       Stratford-Upon-Avon
# 55468                East Sheen
# 55552                     Lewes
# 55609               Oxfordshire
# 55617                        UK
# 55648                 Greenwich
# 55659                Kenilworth
# 55704           Gloucestershire
# 55711                   Andover
# 55739                    London
# 55743                    London
#
#                                                Company   ContractType  \
# 37676                   ITN Mark Education London City  non-specified
# 38775                                 Adam Recruitment      full_time
# 50753                                  SEC Recruitment      full_time
# 50775                                              BPS      full_time
# 50782                         Euro London Appointments      full_time
# 50824                              Penguin Recruitment      full_time
# 50832                                              NaN      full_time
# 50850                                   Howard Jackson      full_time
# 50853                                         Gi Group      full_time
# 50861                                    MAJOR PLAYERS      full_time
# 50890                                     ASTON CARTER      full_time
# 50962                       Rise Technical Recruitment      full_time
# 50968                              New Leaf Search Ltd      full_time
# 50971                 Northern Employment Services Ltd      full_time
# 50974                             Morson International      full_time
# 50981                             The Recruitment Room      full_time
# 50989                             Incisive Recruitment      full_time
# 50990            PTHR International Restaurants & Bars      full_time
# 50998                                  Hays Healthcare      part_time
# 51010                                 The Works Uk Ltd      full_time
# 51014                        Absolute Solution Limited      full_time
# 51064               Holden Jones Financial Recruitment      full_time
# 51077                                Absolute Solution      full_time
# 51112                         Major Technical Services      full_time
# 51145                                Benchmark Recruit      full_time
# 51146                                     Adecco Group      full_time
# 51173                                      Kinetic Plc      full_time
# 51178                             Matchtech Group plc.      full_time
# 51185                      Flame Health Associates LLP      full_time
# 51201                                     Blue Pelican      full_time
# 51206                                 Language Matters      full_time
# 51212                                     Watson Moore      full_time
# 51233                           Advantage Professional      full_time
# 51242                                    Major Players      full_time
# 51243                            Eames Consulting Risk      full_time
# 51250                   Time Recruitment Solutions Ltd      full_time
# 51252                            Morson International.      full_time
# 51266                             Matchtech Group plc.      full_time
# 51270                             Goldstar Recruitment      full_time
# 51290                               Purple Consultancy      full_time
# 51300                                           Altran      full_time
# 51327                             Livewire Recruitment      full_time
# 51341                        Gravitas Recruitment  Ltd      full_time
# 51422                            Solutions Recruitment      full_time
# 51434                                Fusion People Ltd      full_time
# 51466                                  STEP ENTERPRISE      full_time
# 51471                                              NaN      part_time
# 51513                                              NaN      full_time
# 51514                                    ASQ EDUCATION      full_time
# 51526                                    The A24 Group      part_time
# 51551                                           hyphen      full_time
# 51565                                              NaN      full_time
# 51578                      Reed Specialist Recruitment      full_time
# 51586                        Diamond Recruitment Group      full_time
# 51605                                          Redhill      full_time
# 51616                                    TeacherActive      full_time
# 51623                                      STR Limited      full_time
# 51625                                 Atlantis Medical      full_time
# 51638                                            Amdas      full_time
# 51691            UNKNOWN   auto added by vacany import      full_time
# 51770                                Medacs Healthcare      full_time
# 51786                  Berkeley Scott Chef Recruitment      full_time
# 51793                                  Matchtech Group      full_time
# 51794                                       Concept IT      full_time
# 51825                                              NaN      full_time
# 51836                                    Redline Group      full_time
# 51846                                    UKStaffsearch      full_time
# 51847                                  Hillrich People      full_time
# 51848                                              RZ       full_time
# 51867                           Page Personnel Finance      full_time
# 51889                                              NaN      full_time
# 51899                                  Reuben Sinclair      full_time
# 51933                                  N E Recruitment      full_time
# 51939                            Informatiq Consulting      full_time
# 51946                                  Hays Healthcare      part_time
# 51970                                         Randstad      full_time
# 51975                       Bee Recruitment London Ltd      full_time
# 52001                            Sam Small Recruitment      full_time
# 52002                                     ANSON MCCADE      full_time
# 52060                               Arc IT Recruitment      full_time
# 52104                                      Spectrum IT      full_time
# 52106                              Royall Appointments      full_time
# 52127                         Anglian Home Improvement      full_time
# 52129                                   Nonstop Pharma      full_time
# 52188                 Mortimer Bell International Ltd.      full_time
# 52228                    Connect Financial Recruitment      full_time
# 52253                              Recruiting for Care      full_time
# 52259                       Rise Technical Recruitment      full_time
# 52278                                              PSD      full_time
# 52283                             Workshop Recruitment      full_time
# 52337                                            PULSE      full_time
# 52346                              Advance Recruitment      full_time
# 52348                              Exclusive Education      full_time
# 52356                     Castlerock Recruitment Group      full_time
# 52397                                    Austin Andrew      full_time
# 52406                                    CV Screen Ltd      full_time
# 52423                                     Adecco Group      full_time
# 52440              BWB Associates trading as BW Penman      full_time
# 52447                      Direct Response Recruitment      full_time
# 52454                                    cer Financial      full_time
# 52475                                 Pulse Healthcare      full_time
# 52476                        Euro Projects Recruitment      full_time
# 52495                                  RIG Social Care      full_time
# 52496                        SkyBlue Solutions   Leeds      full_time
# 52504                                              IPS      full_time
# 52509                               Towngate Personnel      full_time
# 52527                                 Computer Futures      full_time
# 52532                           Star Actuarial Futures      full_time
# 52550                               Synarbor Education      full_time
# 52558                                     UK Local Ltd      full_time
# 52574                                Meridian Manpower      part_time
# 52578                       Rise Technical Recruitment      full_time
# 52714                                      Blue Eskimo      full_time
# 52723                                      London4Jobs      full_time
# 52770                                              NaN      full_time
# 52852                                    ACADEMICS LTD      full_time
# 52856                               Secta Appointments      full_time
# 52866                  Peninsula Business Services Ltd      full_time
# 52897                                     IT Executive      full_time
# 52900                                      HCL Nursing      full_time
# 52910                  Michael Page Financial Services      full_time
# 52913                                  Coyle Personnel      full_time
# 52920                                Ceema Recruitment      full_time
# 52923                               Automation Experts      full_time
# 52924                                Akton Recruitment      full_time
# 52927                          Aspire Data Recruitment      full_time
# 53017                               Recruitment Genius      full_time
# 53036                   Language Recruitment Services.      full_time
# 53042                       Rise Technical Recruitment      full_time
# 53064                                Polar Recruitment      full_time
# 53087                                        CVbrowser      full_time
# 53095                                              NaN      full_time
# 53100                                  PURPLE SQUIRREL      full_time
# 53102                       Enterprise Recruitment Ltd      full_time
# 53105                               Persuto Automotive      full_time
# 53109                                   BS Social Care      full_time
# 53114                                        CVbrowser      full_time
# 53119                               Regent Recruitment      full_time
# 53138                  Wheale Thomas Hodgins   Bristol      full_time
# 53151                             Matchtech Group plc.      full_time
# 53161                          Aarca Sales Recruitment      full_time
# 53172                               Logistics Job Shop      full_time
# 53198                            White Recruitment Ltd      full_time
# 53229                 The Graduate Recruitment Company      full_time
# 53275                        Hays Internal Recruitment      full_time
# 53281                            SOLOS Consultants Ltd      full_time
# 53288                              TBS Recruitment Ltd      part_time
# 53292                                     CPS Group UK      full_time
# 53293                      Vitae Financial Recruitment      full_time
# 53319                                      Hiredonline      part_time
# 53331                          Allied Healthcare Group      full_time
# 53341        Capita Resourcing Social Care and Housing      full_time
# 53350                                  Jamie's Italian      full_time
# 53353                                              JTG      full_time
# 53391                                       4MYSCHOOLS      part_time
# 53393                         Bridgewater Resources UK      full_time
# 53445                          Aspire Data Recruitment      full_time
# 53454                 Platinum Recruitment Consultancy      full_time
# 53467                       Benjamin James Consultancy      full_time
# 53478                               Niagara Healthcare      full_time
# 53508                            Solutions2Recruitment      part_time
# 53532                                Active Assistance      full_time
# 53536                        Henry Nicholas Associates      full_time
# 53538                            Amrec Recruitment Ltd      full_time
# 53668                            Barchester Healthcare      full_time
# 53704                                       H&R Talent      full_time
# 53724                       Time Recruitment Solutions      full_time
# 53734                 The Management Recruitment Group      full_time
# 53746                          Robert Half   Guildford      full_time
# 53747                                  ESP RECRUITMENT      full_time
# 53749                             Liquid Personnel Ltd      part_time
# 53767                                     Randstad CPE      full_time
# 53792                                 MW Appointments.      full_time
# 53795                                 TTCS RECRUITMENT      full_time
# 53842                                        Dragonfly      full_time
# 53853                           Optimus Search Limited      full_time
# 53857                               Populus Healthcare      full_time
# 53890               Accord Management Services Limited      full_time
# 53930                    Badenoch & Clark   Edinburgh.      full_time
# 53945  Hays Specialist Recruitment   Further Education      full_time
# 53969                  Hot Recruitment Consultants Ltd      full_time
# 53974                                  SYK Recruitment      full_time
# 54020                                Talentweb Limited      full_time
# 54025                                         SF Group      full_time
# 54028                                      CHM Recruit      full_time
# 54032                           Blue Arrow   Guildford      full_time
# 54035                                              NaN      full_time
# 54062                           not 4 profit personnel      full_time
# 54067                                   The Bridge Ltd      full_time
# 54074                            Your World Healthcare      full_time
# 54088                                            Modis      full_time
# 54094                                   Randstad Sales      full_time
# 54131                                Capita Resourcing      full_time
# 54139                                   Robertson Bell      full_time
# 54140                                Toast Recruitment      full_time
# 54169                  Evolution Recruitment Solutions      full_time
# 54198                                              NaN      full_time
# 54201                           Avanti Recruitment Ltd      full_time
# 54203                       Encore Technical Solutions      full_time
# 54205                    Concept Recruitment Group Ltd      full_time
# 54214                            Interaction   Watford      full_time
# 54230                            Pollinate Recruitment      full_time
# 54266                                  Gold Group Ltd.      full_time
# 54283                               At Peak Resourcing      full_time
# 54292                     Executive Resource Group Ltd      full_time
# 54303                                 Remedy Education      full_time
# 54306                                              NaN      part_time
# 54310                                  Hamilton Mayday      full_time
# 54313                      Hays Specialist Recruitment      full_time
# 54316                                    PMP Solutions      full_time
# 54331                                    Saga Homecare      full_time
# 54333                                   TTM Healthcare      full_time
# 54369                                 Interquest Group      full_time
# 54378                           Support Services Group      full_time
# 54406                                              ERS      full_time
# 54419                              Triumph Consultants      full_time
# 54467                                 Recruitment 2000      full_time
# 54480                                SAUCE RECRUITMENT      full_time
# 54487                           Prime Time Recruitment      full_time
# 54490                       Glen Callum Associates Ltd      full_time
# 54491                             Royal British Legion      full_time
# 54493                                     Adecco Group      full_time
# 54507                              Inspired Selections      full_time
# 54539                                    The One Group      full_time
# 54559                                     JGB Partners      full_time
# 54565                          Aarca Sales Recruitment      full_time
# 54568                             Gerrell Hard Limited      full_time
# 54569                                    Gerrard White      full_time
# 54606                                Millar Associates      full_time
# 54634                        Barchester Healthcare Plc      full_time
# 54656                                              AXA      full_time
# 54676                                        Matchtech      full_time
# 54710                           Macildowie Associates.      full_time
# 54715                                  JS3 Recruitment      full_time
# 54734                     Precis Recruitment Solutions      full_time
# 54822                Phoenix Resourcing Services   PRS      full_time
# 54826                                PPA Education Ltd      full_time
# 54828               Rise Technical Recruitment Limited      full_time
# 54830                                  Reed Technology      full_time
# 54838        Capita Resourcing Social Care and Housing      full_time
# 54844                           Castlerock Recruitment      full_time
# 54906                              Penguin Recruitment      full_time
# 54942            AES TECHNICAL & EXECUTIVE CONSULTANTS      full_time
# 54968                                     IT Executive      full_time
# 54982                                 DT Personnel Ltd      full_time
# 54997                     Estio Technology Recruitment      full_time
# ...
# 51848  2012-02-14 00:00:00  2012-05-14 00:00:00  www.jobhuntlisting.com
# 51867  2013-06-09 12:00:00  2013-07-09 12:00:00  www.jobhuntlisting.com
# 51889  2012-11-02 00:00:00  2012-12-02 00:00:00  www.jobhuntlisting.com
# 51899  2013-05-29 12:00:00  2013-07-28 12:00:00  www.jobhuntlisting.com
# 51933  2012-12-20 00:00:00  2013-01-03 00:00:00  www.jobhuntlisting.com
# 51939  2012-02-11 15:00:00  2012-04-11 15:00:00  www.jobhuntlisting.com
# 51946  2012-09-09 15:00:00  2012-11-08 15:00:00  www.jobhuntlisting.com
# 51970  2013-04-10 00:00:00  2013-07-09 00:00:00  www.jobhuntlisting.com
# 51975  2012-08-28 12:00:00  2012-09-27 12:00:00  www.jobhuntlisting.com
# 52001  2012-01-04 15:00:00  2012-03-04 15:00:00  www.jobhuntlisting.com
# 52002  2013-07-04 15:00:00  2013-09-02 15:00:00  www.jobhuntlisting.com
# 52060  2012-12-25 00:00:00  2013-01-24 00:00:00  www.jobhuntlisting.com
# 52104  2013-08-09 15:00:00  2013-10-08 15:00:00  www.jobhuntlisting.com
# 55124  2013-07-05 00:00:00  2013-10-03 00:00:00  www.jobhuntlisting.com
# 55125  2013-07-13 00:00:00  2013-10-11 00:00:00  www.jobhuntlisting.com
# 55166  2012-01-13 00:00:00  2012-01-27 00:00:00  www.jobhuntlisting.com
# 55174  2013-12-20 15:00:00  2014-02-18 15:00:00  www.jobhuntlisting.com
# 55175  2013-07-26 00:00:00  2013-08-25 00:00:00  www.jobhuntlisting.com
# 55201  2012-08-25 15:00:00  2012-09-24 15:00:00  www.jobhuntlisting.com
# 55223  2013-12-31 00:00:00  2014-01-30 00:00:00  www.jobhuntlisting.com
# 55233  2013-02-18 12:00:00  2013-04-19 12:00:00  www.jobhuntlisting.com
# 55238  2013-06-12 15:00:00  2013-07-12 15:00:00  www.jobhuntlisting.com
# 55240  2012-11-04 15:00:00  2012-12-04 15:00:00  www.jobhuntlisting.com
# 55255  2012-04-19 12:00:00  2012-05-19 12:00:00  www.jobhuntlisting.com
# 55353  2012-01-28 00:00:00  2012-02-27 00:00:00  www.jobhuntlisting.com
# 55374  2012-07-16 15:00:00  2012-10-14 15:00:00  www.jobhuntlisting.com
# 55381  2013-05-04 15:00:00  2013-06-03 15:00:00  www.jobhuntlisting.com
# 55398  2013-06-06 00:00:00  2013-08-05 00:00:00  www.jobhuntlisting.com
# 55410  2013-12-15 12:00:00  2014-03-15 12:00:00  www.jobhuntlisting.com
# 55424  2012-11-03 00:00:00  2013-01-02 00:00:00  www.jobhuntlisting.com
# 55428  2012-11-27 15:00:00  2013-02-25 15:00:00  www.jobhuntlisting.com
# 55456  2012-08-24 00:00:00  2012-09-23 00:00:00  www.jobhuntlisting.com
# 55468  2013-06-13 00:00:00  2013-09-11 00:00:00  www.jobhuntlisting.com
# 55552  2012-09-15 00:00:00  2012-10-15 00:00:00  www.jobhuntlisting.com
# 55609  2012-05-29 15:00:00  2012-06-28 15:00:00  www.jobhuntlisting.com
# 55617  2013-06-06 15:00:00  2013-07-06 15:00:00  www.jobhuntlisting.com
# 55648  2013-11-21 12:00:00  2013-12-05 12:00:00  www.jobhuntlisting.com
# 55659  2013-05-22 00:00:00  2013-07-21 00:00:00  www.jobhuntlisting.com
# 55704  2013-05-26 00:00:00  2013-06-25 00:00:00  www.jobhuntlisting.com
# 55711  2013-03-10 12:00:00  2013-04-09 12:00:00  www.jobhuntlisting.com
# 55739  2013-02-05 15:00:00  2013-04-06 15:00:00  www.jobhuntlisting.com
# 55743  2012-10-12 12:00:00  2012-10-26 12:00:00  www.jobhuntlisting.com

# %% [markdown]
# These job advertisments are reasonably **dropped**.

# %%
merged_df = merged_df.drop_duplicates(subset=['Title', 'Company'])

# %%
# check whether there are duplicate job advertisements left
duplicates_jobs = merged_df[merged_df.duplicated(subset=['Title', 'Company'])]
print("Number of duplicates based on title and company:")
display(duplicates_jobs.shape[0])
# Out:
# Number of duplicates based on title and company:
# 0

# %% [markdown]
# ### 5. Saving the integrated and reshaped data
# Export output data to csv format, named as:
# - 'dataset_integrated.csv'

# %%
merged_df.to_csv('dataset_integrated.csv', index=False)
